# %% [markdown]
# # 🧮 Arithmetic Operators – Practice Questions (25 Total)
#
# ## ⭐ Level 1 — Beginner (Simple Calculations)
#
# 1. Add two numbers: 15 + 27
# 2. Subtract two numbers: 100 − 45
# 3. Multiply two numbers: 12 × 8
# 4. Divide two numbers: 144 ÷ 12
# 5. Find remainder: 29 % 4
# 6. Use floor division: 25 // 4
# 7. Use exponent operator: 5 ** 3
# 8. Calculate the total price:
#    A pen costs ₹12, you buy 7 pens. Find the total cost.
# 9. Convert minutes to seconds (1 minute = 60 sec).
# 10. Find the average of three numbers: 10, 20, 30.
#
# ---
#
# ## ⭐⭐ Level 2 — Intermediate (Logic + Operators)
#
# 11. Take a number and check if it is even using `%`.
# 12. Given a number **n**, print its square and cube using `**`.
# 13. Find the last digit of a number using `% 10`.
# 14. Convert Celsius to Fahrenheit using the formula:
#     `F = (C * 9/5) + 32`
# 15. A worker earns ₹250 per day. Calculate earnings for 30 days.
# 16. A shop gives 18% discount on ₹5000. Find the discount amount.
# 17. Use floor division to divide 2 friends’ ages and print the result.
# 18. Compute the perimeter of a rectangle using `2*(l + b)`.
# 19. Compute the area of a circle using formula:
#     `π * r * r` (use π = 3.14)
# 20. Calculate compound multiplication:
#     Find 2 × 2 × 2 × 2 × 2 using `**`.
#
# ---
#
# ## ⭐⭐⭐ Level 3 — Advanced/Tricky
#
# 21. Given a 4-digit number, find the **sum of all digits** using `%` and `//`.
# 22. Reverse a 3-digit number using `%` and `//`.
# 23. A person earns ₹50,000 salary and spends 27% on rent.
#     Use arithmetic to calculate how much is left.
# 24. Using `//` and `%`, separate **hours and minutes** from total minutes (e.g., 135 mins → 2 hrs 15 mins).
# 25. Using arithmetic only (no strings), check if a 3-digit number is an **Armstrong number**.
#     Example: 153 → 1³ + 5³ + 3³ = 153

# %% [markdown]
# # 🔍 Python Logical Operators – 25 Practice Questions
# Logical operators in Python:
# - `and`
# - `or`
# - `not`
#
# Use these questions to practice conditions, logic building, and boolean expressions.
#
# ---
#
# ## 🟢 Level 1: Easy (Basics)
#
# 1. Write a condition using `and` that checks if a number is **between 1 and 10**.
# 2. Check if a number is **positive OR even**.
# 3. Use `not` to check if a user is **not** above 18.
# 4. Use `and` to check if a character is a **lowercase vowel**.
# 5. Check if a number is **NOT equal to 5** using `not`.
# 6. Check if a string is `"python"` or `"Python"`.
# 7. Use `and` to verify:
#    Age is above 18 **and** income is above 20,000.
# 8. Check if a list is **not empty** using `not`.
# 9. Check if a number is **not divisible by 2**.
# 10. Use `or` to check if a user entered `"yes"` or `"y"`.
#
# ---
#
# ## 🟡 Level 2: Medium (With Conditions)
#
# 11. Check if a student passes: marks > 40 **and** attendance > 75.
# 12. Check if a year is a **century year** or **a leap year**.
# 13. Check if temperature is safe: (temp > 20 **and** temp < 35).
# 14. Check if a person is a **teenager** using logical operators.
# 15. Check if a string does **not contain** the letter `"a"` using `not` and `in`.
# 16. Verify if a password length is > 8 **and** it contains `"@"`.
# 17. Check if a character is **not a digit**.
# 18. Check if a number is divisible by 3 **or** 5.
# 19. Use `and` + `not` to verify:
#     A number is positive **and not** greater than 100.
# 20. Check if a list contains 2 **or** 3.
#
# ---
#
# ## 🔴 Level 3: Hard (Logical Thinking)
#
# 21. Check if a number is between 100 and 200 **or** between 500 and 600.
# 22. Check if **not (x > 10 and x < 20)** is true for a number.
# 23. Verify if a string starts with `"A"` **and** does not end with `"Z"`.
# 24. Check if a triangle is valid:
#     (a + b > c) **and** (a + c > b) **and** (b + c > a).
# 25. Check if a user is allowed:
#     - age >= 18
#     - has ID card
#     - (country == "India" **or** country == "USA")

# %% [markdown]
# # 🟩 25 Practice Questions: Relational Operators in Python
# Relational operators compare two values and return **True/False**.
# They include: `>`, `<`, `>=`, `<=`, `==`, `!=`
#
# ---
#
# ## 🔰 Level 1: Beginner (Simple Comparisons)
#
# 1. Check if 10 is greater than 5.
# 2. Check if 7 is less than 3.
# 3. Check if 15 is equal to 15.
# 4. Check if 20 is not equal to 10.
# 5. Check if 8 is greater than or equal to 8.
# 6. Check if 3 is less than or equal to 1.
# 7. Compare two variables `a` and `b` and print whether `a == b`.
# 8. Compare two numbers and print whether the first is greater.
# 9. Check if a number entered by the user is greater than 100.
# 10. Check if the age variable is equal to 18.
#
# ---
#
# ## 🟦 Level 2: Intermediate (Comparisons Inside Conditions)
#
# 11. Ask the user for their age and check if they are **eligible to vote** (age ≥ 18).
# 12. Check if a number is **positive**, **negative**, or **zero** using relational operators.
# 13. Given three numbers, determine the **smallest** using relational comparisons.
# 14. Check if a number is between **1 and 50** (exclusive).
# 15. Compare the length of two strings using `len()`.
# 16. Ask the user to enter a password and check if it matches `"python123"`.
# 17. Given two values, print whether they are **not equal**.
# 18. Compare two floating-point numbers and print the larger one.
# 19. Check if the first character of a string is equal to `'A'`.
# 20. Check if the last element of a list is greater than 10.
#
# ---
#
# ## 🟥 Level 3: Advanced (Logic with Relational Operators)
#
# 21. Check if a number is a valid **3-digit** number (100 to 999 inclusive).
# 22. Ask for two numbers and check if both are even (use relational + modulo).
# 23. Check if a student's score is in the **passing range** (35 to 100).
# 24. Compare the areas of two rectangles using relational operators.
# 25. Given age and country, check if someone is eligible for **driving license** (e.g., age ≥ 18 AND country == "India").

# %% [markdown]
# # While Loops
# ---
#
# # Level 1 — Easy (10 Questions)
#
# 1. Print numbers from 1 to 10 using a for loop.
# 2. Print all even numbers from 2 to 20.
# 3. Print each character in the string `"Python"`.
# 4. Print items from the list: `["apple", "banana", "mango"]`.
# 5. Print squares of numbers from 1 to 5.
# 6. Print numbers from 10 down to 1 using `range()`.
# 7. Count how many times `"a"` appears in a string.
# 8. Print the multiplication table of 5.
# 9. Print all elements and their indexes from a list.
# 10. Print numbers from 0 to 50 with a step of 10.
#
# ---
#
# # Level 2 — Medium (10 Questions)
#
# 11. Print all odd numbers between 1 and 100.
# 12. Print the sum of numbers from 1 to 100.
# 13. From a list of numbers, print only the even ones.
# 14. Find the largest number in a list using a for loop.
# 15. Reverse a string using a for loop (no slicing allowed).
# 16. Count how many vowels are in a string.
# 17. Create a new list containing squares of all numbers in another list.
# 18. Print numbers divisible by both 3 and 5 between 1 and 100.
# 19. Loop through a dictionary and print each key and value.
# 20. Print the first 10 multiples of 7.
#
# ---
#
# # Level 3 — Hard (5 Questions)
#
# 21. Print the first 10 Fibonacci numbers using a for loop.
# 22. Print this pattern:

# %% [markdown]
# \*
#
# \**
#
# \***
#
# \****
#
# \*****
#
# 23. Print this pattern :
#
# 5
#
# 54
#
# 543
#
# 5432
#
# 54321

# %% [markdown]
# 24. Given a list, count how many numbers are positive, negative, and zero.
# 25. Given a list of strings, print only the strings that start with a vowel.

# %% [markdown]
# # Python While Loop Practice — 3 Levels of Difficulty
#
# ---
#
# # Level 1 — Beginner (10 Questions)
# 1. Print numbers from 1 to 10 using a `while` loop.
# 2. Print "Hello" 5 times using a `while` loop.
# 3. Print even numbers from 2 to 20.
# 4. Print numbers from 10 down to 1.
# 5. Print the multiplication table of 6 using a `while` loop.
# 6. Print all odd numbers from 1 to 25.
# 7. Print the sum of numbers from 1 to 50 using a `while` loop.
# 8. Keep printing numbers starting from 1 until the number becomes 15.
# 9. Start from 5, keep adding 5, and stop when you reach 50.
# 10. Start from 100, keep subtracting 10 until you reach 0.
#
# ---
#
# # Level 2 — Intermediate (10 Questions)
# 11. Keep asking the user for input until they type `"stop"`.
# 12. Ask the user to guess a number until they get it correct.
# 13. Count how many digits a number has using a `while` loop.
# 14. Count how many vowels are in a string using a `while` loop.
# 15. Reverse a string using a `while` loop (no slicing).
# 16. Keep doubling a number starting from 1 until it becomes greater than 500.
# 17. Print squares of numbers from 1 to 15 using a `while` loop.
# 18. Count how many times you can divide 1000 by 2 until it becomes less than 1.
# 19. Keep asking for numbers and stop only when the sum crosses 100.
# 20. Print all characters in a string but stop when you reach the letter `"a"`.
#
# ---
#
# # Level 3 — Advanced (5 Questions)
# 21. Check if a number is a palindrome using a `while` loop.
# 22. Print the first 12 Fibonacci numbers using a `while` loop.
# 23. Create a simple menu program that runs forever until the user selects “Exit”.
# 24. Using a `while` loop, print all numbers between 1 and 300 that are divisible by **both 4 and 6**.
# 25. Write a program that keeps reading numbers from the user and prints the **largest** one so far, stopping only when the user enters `-1`.

# %% [markdown]
# # 🟦 Python If–Else Practice Questions (30 Problems)
#
# ## 🔰 Level 1 — Easy (Basics)
#
# 1. Check if a number is positive or negative.
# 2. Check if a number is even or odd.
# 3. Check whether a person is eligible to vote (age ≥ 18).
# 4. Check if a number is divisible by 5.
# 5. Check if a number is divisible by both 2 and 3.
# 6. Take a username as input; print “Welcome” if it's “admin”.
# 7. Take a number and print “Small” if less than 10 else print “Big”.
# 8. Check if a character is a vowel or consonant.
# 9. Take two numbers and print which one is larger.
# 10. Check whether a number is single-digit or multi-digit.
#
# ---
#
# ## 🟧 Level 2 — Medium (Logic + Conditions)
#
# 11. Check if a given year is a leap year.
# 12. Compare three numbers and print the largest.
# 13. Check if a student passed the exam (marks ≥ 40).
# 14. Take two numbers and check if both are even.
# 15. Check if a number is within the range 1 to 100.
# 16. Check if a number is a multiple of 7 or 11.
# 17. Input temperature:
#    - Above 30 → “Hot”
#    - 15–30 → “Warm”
#    - Below 15 → “Cold”
# 18. Check if a person qualifies for a loan (salary > 30k and age > 21).
# 19. Check if a string contains the letter “a”.
# 20. Check whether the length of a string is even or odd.
#
# ---
#
# ## 🟥 Level 3 — Hard (Decision Making + Nested Conditions)
#
# 21. Input marks and print the grade:
#    - ≥ 90 → A
#    - 80–89 → B
#    - 70–79 → C
#    - 60–69 → D
#    - Below 60 → Fail
#
# 22. Simulate login: ask for username and password:
#    - If username is “admin” **and** password is “1234”, print “Login Successful”.
#    - Else print “Access Denied”.
#
# 23. Check if a number is positive, negative, or zero.
#
# 24. Given a number, check:
#    - If divisible by 3 and 5 → “FizzBuzz”
#    - If only divisible by 3 → “Fizz”
#    - If only divisible by 5 → “Buzz”
#    - Else → number itself
#
# 25. Input age and categorize:
#    - 0–12 → Child
#    - 13–19 → Teen
#    - 20–59 → Adult
#    - 60+ → Senior
#
# 26. Check if a triangle is valid (sum of any two sides > third side).
#
# 27. Input three sides and determine the type of triangle:
#    - All equal → Equilateral
#    - Two equal → Isosceles
#    - All different → Scalene
#
# 28. Check if a character is uppercase, lowercase, digit, or special symbol.
#
# 29. Take marks of 5 subjects; calculate average; check if student got distinction (avg ≥ 75).
#
# 30. ATM simulation:
#    - Ask for balance and withdrawal amount.
#    - If withdrawal ≤ balance → “Transaction Successful”
#    - Else → “Insufficient Balance”
